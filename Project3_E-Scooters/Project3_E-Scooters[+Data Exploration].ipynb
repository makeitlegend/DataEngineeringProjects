# %% [markdown]
# #Electric Scooters

# %%
#link to the Kaggle dataset -> https://www.kaggle.com/datasets/marcom01/e-scooter-rides-vibration?utm_source=chatgpt.com

import pandas as pd
import numpy as np

# %% [markdown]
# ##Data Exploration

# %%
df_e_scooters = pd.read_csv("/content/E-ScootersData.csv")

# %%
df_e_scooters.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61500 entries, 0 to 61499
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   index      61500 non-null  int64
#  1   timestamp  61500 non-null  object
#  2   acc_x      61500 non-null  float64
#  3   acc_y      61500 non-null  float64
#  4   acc_z      61500 non-null  float64
#  5   time       61500 non-null  float64
#  6   label      61500 non-null  object
#  7   sample     61500 non-null  int64
# dtypes: float64(4), int64(2), object(2)
# memory usage: 3.8+ MB

# %%
df_e_scooters.describe()
# Out:
#               index         acc_x         acc_y         acc_z          time  \
# count  61500.000000  61500.000000  61500.000000  61500.000000  61500.000000
# mean   30749.500000      0.887616      0.001898     -0.407703    308.592581
# std    17753.665115      0.527449      0.165028      0.230069    177.882442
# min        0.000000     -6.062500     -3.078125     -7.796875      0.000000
# 25%    15374.750000      0.812500     -0.046875     -0.484375    154.648500
# 50%    30749.500000      0.875000     -0.015625     -0.421875    308.783000
# 75%    46124.250000      0.968750      0.062500     -0.343750    462.651250
# max    61499.000000      7.984375      3.078125      4.671875    616.379000
#
#              sample
# count  61500.000000
# mean   30749.500000
# std    17753.665115
# min        0.000000
# 25%    15374.750000
# 50%    30749.500000
# 75%    46124.250000
# max    61499.000000
